# %%
import numpy as np

# %%
revenue = np.array([[180,200,220],[24,36,40],[12,18,20]])
expenses = np.array([[80,90,100],[10,16,20],[8,10,10]])

# %%
revenue
# Out:
# array([[180, 200, 220],
#        [ 24,  36,  40],
#        [ 12,  18,  20]])

# %%
profit = revenue - expenses
profit
# Out:
# array([[100, 110, 120],
#        [ 14,  20,  20],
#        [  4,   8,  10]])

# %%
no_of_units = np.array([[30,40,50],[5,10,15],[2,5,7]])
price_per_unit = np.array([1000,400,1200])

# %%
total_sale = np.dot(price_per_unit,no_of_units)
total_sale
# Out:
# array([[34400, 50000, 64400]])

# %%
revenue_dollar = np.array([[200,220,250],[68, 79, 105],[110,140,180],[80,85,90]])
inr_price = 75

# %%
converting_price = revenue_dollar * inr_price
converting_price
# Out:
# array([[15000, 16500, 18750],
#        [ 5100,  5925,  7875],
#        [ 8250, 10500, 13500],
#        [ 6000,  6375,  6750]])
