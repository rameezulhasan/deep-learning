# %%
import matplotlib.pyplot as plt

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")

# %%
from IPython import display
display.Image("./image.jpg", width=300, height=300)

# %%
pred = model.predict("./image.jpg")
# Out:
# image 1/1 E:\Visual Studio\Complete Visual Studio\Data Science\Deep Learning\deep-learning\9. Object Detection using Yolo\image.jpg: 640x640 2 bottles, 361.7ms
# Speed: 9.1ms preprocess, 361.7ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
len(pred)
# Out:
# 1

# %%
pred[0].show()

# %%
import matplotlib.pyplot as plt

img = pred[0].plot()

plt.imshow(img)
plt.axis("off")
plt.show()

# %%
from PIL import Image
import gradio as gr

# %%
def objectDetection(image):
  pred = model.predict(image)
  predict_image = pred[0].plot()
  return Image.fromarray(predict_image)

# %%
app = gr.Interface(fn=objectDetection, inputs="image", outputs='image', title="Object Detection")

# %%
app.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 0: 640x640 2 bottles, 1 knife, 375.8ms
# Speed: 9.8ms preprocess, 375.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 keyboard, 1 clock, 1 scissors, 382.5ms
# Speed: 9.6ms preprocess, 382.5ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 448x640 5 persons, 458.2ms
# Speed: 3.6ms preprocess, 458.2ms inference, 34.6ms postprocess per image at shape (1, 3, 448, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 339.6ms
# image 2/2 C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 308.6ms
# Speed: 5.5ms preprocess, 324.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 301.0ms
# image 2/2 C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 241.7ms
# Speed: 4.9ms preprocess, 271.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 315.5ms
# image 2/2 C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 251.7ms
# Speed: 7.8ms preprocess, 283.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 355.1ms
# Speed: 7.8ms preprocess, 355.1ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 (no detections), 274.2ms
# Speed: 3.1ms preprocess, 274.2ms inference, 4.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 5 persons, 272.4ms
# Speed: 3.2ms preprocess, 272.4ms inference, 4.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 250.6ms
# Speed: 6.2ms preprocess, 250.6ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
