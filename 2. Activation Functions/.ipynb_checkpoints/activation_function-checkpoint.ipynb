# %%
import tensorflow as tf
import numpy as np
import math

# %%
import tensorflow as tf

input_values = tf.constant([100, 1, -5, -30], dtype=tf.float32)
sigmoid_func = tf.math.sigmoid(input_values)

print(sigmoid_func.numpy())

#    or 

def sigmoid(x):
    return 1/(1 + math.exp(-x))
# Out:
# [1.0000000e+00 7.3105854e-01 6.6928524e-03 9.3576243e-14]

# %%
sigmoid(100)
# Out:
# 1.0

# %%
sigmoid(1)
# Out:
# 0.7310585786300049

# %% [markdown]
# ### Tanh

# %%
input_tensor =([-56.0,50.0,1.0])
tanh_func = tf.math.tanh(input_tensor)
tanh_func.numpy()
# Out:
# array([-1.       ,  1.       ,  0.7615942], dtype=float32)

# %% [markdown]
# ### Relu

# %%
input_values = ([-4, 10, -18, 40])
relu_func = tf.nn.relu(input_values)
relu_func.numpy()
# Out:
# array([ 0, 10,  0, 40], dtype=int32)

# %% [markdown]
# ### Leaky Relu

# %%
def leaky_relu(x):
    return max(0.1*x,x)

# %%
leaky_relu(-100)
# Out:
# -10.0

# %%
leaky_relu(-10)
# Out:
# -1.0
